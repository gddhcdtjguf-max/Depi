# %%
print()

# %%
X="depi.r5
"

# %%
print("my name is.{0} ,my age is.{1}".format("amit",20) )
# Out:
# my name is.amit ,my age is.20

# %%
name="doaa"
course="Machine learning"
output=("my name is {0}, and i am engaged in {1}".format(name,course))
print(output)
# Out:
# my name is doaa, and i am engaged in Machine learning

# %%
x=5
print(type(x))
# Out:
# <class 'int'>

# %%
name=" amit learning"
print("name[5:-1:1]")
# Out:
# name[5:-1:1]
