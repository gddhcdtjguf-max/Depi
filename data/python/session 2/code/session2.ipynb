# %%
list_one=[1,2,3,4],"depi","ml",True,[1,2,3,"True",["ml","dl"]]
list_one
# Out:
# ([1, 2, 3, 4], 'depi', 'ml', True, [1, 2, 3, 'True', ['ml', 'dl']])

# %%
george=li
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 list_one[7][4][0]
#       2 list_one
#
# IndexError: tuple index out of range

# %%
list_2 =["depi","ml","geini"]
list_2.append("deep learning")
print(list_2)
# Out:
# ['depi', 'ml', 'geini', 'deep learning']

# %%
list_2.insert(0,"nlp")
list_2
# Out:
# ['nlp', 'depi', 'ml', 'geini', 'deep learning']

# %%
list_2.extend("doaa")
list_2
# Out:
# ['nlp', 'depi', 'ml', 'geini', 'deep learning', 'd', 'o', 'a', 'a']

# %%
new_list=['nlp', 'depi', 'ml', 'geini', 'deep learning', 'd', 'o', 'a', 'a']
new_list.remove("depi")
print(list_2)
# Out:
# ['nlp', 'depi', 'ml', 'geini', 'deep learning', 'd', 'o', 'a', 'a']

# %%
list_2 =["depi","ml","ai"]
list_2.pop()
print(list_2)
# Out:
# ['depi', 'ml']

# %%
del list_2
print

# %%
name=input("enter your name")
print(name)

# %%
name=input("enter your name")
print(type(name))
# Out:
# <class 'str'>

# %%
input_list= ["amit","learning","python","ml"]
item =input("enter item")
input_list.remove(item)
print(input_list)
# Out:
# ['learning', 'python', 'ml']

# %%
list=[2,2,5,,3,2]
count_2 =list.count(2)

# %%
list=[2,3,4]
list.reverse()
print(list)
# Out:
# [4, 3, 2]

# %%
list =[4,7,5,2]
list.clear()
print(list)
# Out:
# []

# %%
tuple=[2,5,2]
tuple[0]
# Out:
# 2

# %%
number =int(input("enter your id"))
print

# %%
num_2=int(input("enter number"))
num_3=int(input("enter second number"))
print(f"summation:{num_2+num_3}")
print(f"substraction:{num_2-num_3}")
print(f"multi:{num_2*num_3}")
print(f"div:{num_2/num_3}")
# Out:
# summation:6
# substraction:-2
# multi:8
# div:0.5

# %%
a=200
b=33
if b>a:
    print("b is greater than a")
    else:
        print

# %%
degree=float(input("enter your degree"))
if degree<0 and degree>100:
    
 print("invalid")
if degree>=90:

 print("Grade =A")
elif degree>=80 :
 print("Grade =B")
elif degree>=70 :
 print("Grade =C")
if degree>=60:
 print("Grade =D")
else:
    print("Grade =F")
# Out:
# Grade =B
# Grade =D
