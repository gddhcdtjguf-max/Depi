# %%
class Student:
    _id_counter = 1

    def __init__(self, name):
        self.name = name
        self.student_id = Student._id_counter
        Student._id_counter += 1
        self.name = name
        self.grades ={}
        self.enrolled_courses = []
        def __str__(self)->str:
            return f"Student ID: {self.student_id} Name: {self.name}"
        def __repr__(self)->str:
            return f"Student ID: {self.student_id} Name: {self.name}"  

        def add_grade(self, course, grade):
            if not 0<= grade <= 100:
                raise ValueError("Grade must be between 0 and 100.")
            self.grades[course] = grade
        def enroll_course(self, course):
                if course not in self.enrolled_courses:
                    raise ValueError(f"Student is not enrolled in {course}.")
                else:
                    self.enrolled_courses.append(course)

# %%
student1 = Student("doaa")
repr(student1)
student1.add_grade(2, 95)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 3
#       1 student1 = Student("doaa")
#       2 repr(student1)
# ----> 3 student1.add_grade(2, 95)
#
# AttributeError: 'Student' object has no attribute 'add_grade'

# %%
 # str user case

# %%
class Course:
    id_counter = 1
    def __init__(self, name):
        self.name = name
        self.course_id = Course.id_counter
        Course.id_counter += 1
        self. enrolled_students = []

# %%
import unittest
 
class TestStudent(unittest.TestCase):
   
   
    def setUp(self):
        self.student = Student("Faris")
       
    def test_creation(self):
        self.assertEqual(self.student.name, "Faris")
    def test_add_grade(self):
        self.student.add_grade(1, 90)
        self.assertEqual(self.student.grades[1], 90)
    def test_enroll_in_course(self):
        course = Course("Math")
        self.student.enroll_in_course(course)
        self.assertIn(course, self.student.enrolled_courses)
 
 
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# E.E
# ======================================================================
# ERROR: test_add_grade (__main__.TestStudent)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\iamasd\AppData\Local\Temp\ipykernel_19168\4021943220.py", line 12, in test_add_grade
#     self.student.add_grade(1, 90)
# AttributeError: 'Student' object has no attribute 'add_grade'
#
# ======================================================================
# ERROR: test_enroll_in_course (__main__.TestStudent)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\iamasd\AppData\Local\Temp\ipykernel_19168\4021943220.py", line 15, in test_enroll_in_course
#     course = Course("Math")
# NameError: name 'Course' is not defined
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.011s
#
# FAILED (errors=2)

# %%
class Course:
    _id_counter = 1

    def __init__(self, name):
        self.course_id = Course._id_counter
        Course._id_counter += 1
        self.name = name
        self.enrolled_students = []  # قائمة الطلاب المسجلين في هذا الكورس

    def __str__(self):
        return f"Course ID: {self.course_id}, Name: {self.name}, Enrolled: {len(self.enrolled_students)}"

    # تسجيل الطالب في الكورس
    def enroll_student(self, student):
        if student not in self.enrolled_students:
            self.enrolled_students.append(student)
            print(f"Student {student.name} enrolled successfully in {self.name}.")
        else:
            print(f"Student {student.name} is already enrolled in {self.name}.")

    # إزالة الطالب من الكورس الحالي
    def remove_student(self, student):
        if student in self.enrolled_students:
            self.enrolled_students.remove(student)
            print(f"Student {student.name} removed from {self.name}.")
        else:
            print(f"Student {student.name} is not enrolled in {self.name}.")

# %%
s1 = Student("Maha")
s1.add_grade(1, 90)
repr(s1)
str(s1)
s1.enroll_course("Python")
s1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 2
#       1 s1 = Student("Maha")
# ----> 2 s1.add_grade(1, 90)
#       3 repr(s1)
#       4 str(s1)
#
# AttributeError: 'Student' object has no attribute 'add_grade'
